# %%
print("hello world")
# Out:
# hello world

# %%
pip
# Out:
# Usage:
#   c:\Users\majji\OneDrive\Documents\Arduino\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   lock                        Generate a lock file.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --debug                     Let unhandled exceptions propagate outside the
#                               main subroutine, instead of logging them to
#                               stderr.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   --require-virtualenv        Allow pip to only run in a virtual environment;
#                               exit with an error otherwise.
#   --python <python>           Run pip with the specified Python interpreter.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --no-input                  Disable prompting for input.
#   --keyring-provider <keyring_provider>
#                               Enable the credential lookup via the keyring
#                               library if user input is allowed. Specify which
#                               mechanism to use [auto, disabled, import,
#                               subprocess]. (default: auto)
#   --proxy <proxy>             Specify a proxy in the form
#                               scheme://[user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum attempts to establish a new HTTP
#                               connection. (default: 5)
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to PEM-encoded CA certificate bundle. If
#                               provided, overrides the default. See 'SSL
#                               Certificate Verification' in pip documentation
#                               for more information.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.
#   --resume-retries <resume_retries>
#                               Maximum attempts to resume or restart an
#                               incomplete download. (default: 0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\majji\onedrive\documents\arduino\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.8.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: black>=24.10.0 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (6.2.0)
# Collecting kagglesdk<1.0,>=0.1.14 (from kaggle)
#   Downloading kagglesdk-0.1.14-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Downloading mypy-1.19.1-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (24.2)
# Requirement already satisfied: protobuf in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: six>=1.10 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (4.67.1)
# Collecting types-requests (from kaggle)
#   Downloading types_requests-2.32.4.20250913-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from black>=24.10.0->kaggle) (4.3.7)
# Requirement already satisfied: colorama in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from mypy>=1.15.0->kaggle) (4.12.2)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Downloading librt-0.7.5-cp313-cp313-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: webencodings in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kaggle) (2025.4.26)
# Downloading kaggle-1.8.3-py3-none-any.whl (102 kB)
# Downloading kagglesdk-0.1.14-py3-none-any.whl (159 kB)
# Downloading mypy-1.19.1-cp313-cp313-win_amd64.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.1 MB 5.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.1 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.1 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.1 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.1 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.2/10.1 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.1 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.1/10.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 3.9 MB/s eta 0:00:00
# Downloading librt-0.7.5-cp313-cp313-win_amd64.whl (49 kB)
# Downloading types_requests-2.32.4.20250913-py3-none-any.whl (20 kB)
# Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Installing collected packages: types-requests, librt, types-tqdm, mypy, kagglesdk, kaggle
#
#    ------------- -------------------------- 2/6 [types-tqdm]
#   Attempting uninstall: mypy
#    ------------- -------------------------- 2/6 [types-tqdm]
#     Found existing installation: mypy 1.14.1
#    ------------- -------------------------- 2/6 [types-tqdm]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#     Uninstalling mypy-1.14.1:
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#       Successfully uninstalled mypy-1.14.1
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    ---------------------------------------- 6/6 [kaggle]
#
# Successfully installed kaggle-1.8.3 kagglesdk-0.1.14 librt-0.7.5 mypy-1.19.1 types-requests-2.32.4.20250913 types-tqdm-4.67.0.20250809
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\majji\onedrive\documents\arduino\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "Train.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "brijbhushannanda1979/bigmart-sales-data",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\majji\AppData\Local\Temp\ipykernel_51880\913971941.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Downloading from https://www.kaggle.com/api/v1/datasets/download/brijbhushannanda1979/bigmart-sales-data?dataset_version_number=1&file_name=Train.csv...
# 100%|██████████| 849k/849k [00:01<00:00, 502kB/s]
# First 5 records:   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
